# %%
import sys
import os
import subprocess
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import sqlite3


caminho_absoluto = r'C:\Users\lucas\repositorios\mestrado_luedsbr\SRC\analista_cenario'
sys.path.append(caminho_absoluto)

try:
    from analista import *
except ModuleNotFoundError as e:
    print(f" Erro: {e}")

# %%
TOTAL_CEN = 100
script_julia = r"C:\Users\lucas\repositorios\mestrado_luedsbr\SRC\modelos_matematicos\fluxpot_otimo.jl"

for i in range(TOTAL_CEN):
    print(f"Rodando {i+1}/{TOTAL_CEN}")
    
    # Método mais simples possível
    os.system(f'julia "{script_julia}" > nul 2>&1')

print("Todas execuções completas")
# Out:
# Rodando 1/100
# Rodando 2/100
# Rodando 3/100
# Rodando 4/100
# Rodando 5/100
# Rodando 6/100
# Rodando 7/100
# Rodando 8/100
# Rodando 9/100
# Rodando 10/100
# Rodando 11/100
# Rodando 12/100
# Rodando 13/100
# Rodando 14/100
# Rodando 15/100
# Rodando 16/100
# Rodando 17/100
# Rodando 18/100
# Rodando 19/100
# Rodando 20/100
# Rodando 21/100
# Rodando 22/100
# Rodando 23/100
# Rodando 24/100
# Rodando 25/100
# Rodando 26/100
# Rodando 27/100
# Rodando 28/100
# Rodando 29/100
# Rodando 30/100
# Rodando 31/100
# Rodando 32/100
# Rodando 33/100
# Rodando 34/100
# Rodando 35/100
# Rodando 36/100
# Rodando 37/100
# Rodando 38/100
# Rodando 39/100
# Rodando 40/100
# Rodando 41/100
# Rodando 42/100
# Rodando 43/100
# Rodando 44/100
# Rodando 45/100
# Rodando 46/100
# Rodando 47/100
# Rodando 48/100
# Rodando 49/100
# Rodando 50/100
# Rodando 51/100
# Rodando 52/100
# Rodando 53/100
# Rodando 54/100
# Rodando 55/100
# Rodando 56/100
# Rodando 57/100
# Rodando 58/100
# Rodando 59/100
# ...

# %%
analise_simples(db_path=r'C:\Users\lucas\repositorios\mestrado_luedsbr\relatorios\resultados_opf_series.db')
# Out:
# C:\Users\lucas\repositorios\mestrado_luedsbr\relatorios\resultados_opf_series.db
# === RESUMO DOS CENÁRIOS ===
# Total de cenários: 102
#        total_geracao_pu  total_carga_pu  custo_total_usd_h
# count          102.0000        102.0000           102.0000
# mean            36.6778         36.6701        417524.7916
# std              0.1465          0.1464          8329.1396
# min             36.3234         36.3158        400384.1225
# 25%             36.5806         36.5729        409749.1153
# 50%             36.6827         36.6750        418433.2820
# 75%             36.7608         36.7531        424725.1658
# max             37.2084         37.2008        433159.6317
#
# === GRÁFICOS ===
# Rampas da Geração Eólica, Curtailment e Demanda:
#     transicao  rampa_geracao  rampa_curtailment  rampa_demanda  \
# 0         1→2         0.1419             0.0000         0.3602
# 1         2→3         1.5604             1.3606         0.3272
# ...
